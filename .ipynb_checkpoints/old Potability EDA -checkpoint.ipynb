# %%
import pandas as pd

# %%
water = pd.read_csv("water_potability.csv")

# %%
water.shape
# Out:
# (3276, 10)

# %%
water.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
water.hist('ph')
# Out:
# array([[<AxesSubplot:title={'center':'ph'}>]], dtype=object)

# %%
water.plot.scatter('ph','Hardness')
# Out:
# <AxesSubplot:xlabel='ph', ylabel='Hardness'>

# %%
water['ph'].mean()
# Out:
# 7.080794504276835

# %%
water['ph'].median()
# Out:
# 7.036752103833548

# %%
water.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
# Potability      -0.003556 -0.013837  0.033743     0.023779 -0.023577
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.018614        0.043503         0.003354  -0.039057
# Hardness            -0.023915        0.003610        -0.013013  -0.014449
# Solids               0.013831        0.010242        -0.009143   0.019546
# Chloramines         -0.020486       -0.012653         0.017084   0.002363
# Sulfate             -0.016121        0.030831        -0.030274  -0.011187
# Conductivity         1.000000        0.020966         0.001285   0.005798
# Organic_carbon       0.020966        1.000000        -0.013274  -0.027308
# Trihalomethanes      0.001285       -0.013274         1.000000  -0.022145
# Turbidity            0.005798       -0.027308        -0.022145   1.000000
# Potability          -0.008128       -0.030001         0.007130   0.001581
#
#                  Potability
# ph                -0.003556
# Hardness          -0.013837
# Solids             0.033743
# Chloramines        0.023779
# Sulfate           -0.023577
# Conductivity      -0.008128
# Organic_carbon    -0.030001
# Trihalomethanes    0.007130
# Turbidity          0.001581
# Potability         1.000000

# %%
water['Drinkable'] = water['Potability']

# %%
water['Drinkable'].replace({0: 'No', 1:'Yes'}, inplace = True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(3, 3, figsize = (12,12))

sns.stripplot(ax = axs[0, 0], x='ph', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[0, 1], x='Hardness', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[0, 2], x='Solids', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[1, 0], x='Chloramines', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[1, 1], x='Sulfate', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[1, 2], x='Conductivity', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[2, 0], x='Organic_carbon', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[2, 1], x='Trihalomethanes', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
sns.stripplot(ax = axs[2, 2], x='Turbidity', y='Drinkable', data=water, order = ['Yes', 'No'],
              jitter = 0.4, linewidth=1, alpha = 0.3, 
              edgecolor = 'k', palette="RdYlGn_r")
# Out:
# <AxesSubplot:xlabel='Turbidity', ylabel='Drinkable'>

# %%
features = water.drop(columns = 'Potability').columns

# %%
X = water[features]

# %%
target = water['Potability']

y = target

# %%
from sklearn.model_selection import train_test_split

X_model, X_holdout, y_model, y_holdout = train_test_split(X, y, test_size=0.25, random_state=42, stratify = y)

# %%
pd.concat([X_holdout, y_holdout.to_frame()], axis=1).to_csv('holdout_set.csv')

# %%
pd.concat([X_model, y_model.to_frame()], axis=1).to_csv('model_set.csv')

# %%
water = pd.read_csv('model_set.csv', index_col = 'Unnamed: 0')

# %%
water
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2118  8.884935  145.277706  17621.390115     8.267974  341.477474
# 1567       NaN  187.043283  24634.552443     9.081880         NaN
# 69    7.261551  179.889788  24964.777703     5.837086  349.269271
# 2439  7.895769  168.724047  28723.617627     9.341475  353.976181
# 1582  9.723377  190.897421   9076.646483     9.752088  357.384709
# ...        ...         ...           ...          ...         ...
# 101   7.348845  223.264940  11519.046527     8.889559         NaN
# 1734  3.928556  191.665998  17328.161457     7.692417  306.479558
# 1071  7.774468  216.752872  22316.398284     7.947534  385.043438
# 2924  7.833980  203.169408  11174.274760     6.246502  394.890809
# 1207       NaN  221.675463  10117.084438     8.026586  356.211614
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2118    286.890777       15.194724        42.289054   4.714163           0
# 1567    443.843399       11.053925        74.108180   3.498717           1
# 69      501.182781       17.287713        50.993006   3.636364           0
# 2439    517.436676       11.992772        79.860552   4.391731           1
# 1582    443.037417       13.307824        62.826687   4.072063           1
# ...            ...             ...              ...        ...         ...
# 101     494.158434       18.145374        73.715522   4.880875           0
# 1734    406.085614        9.578602        45.480738   5.060836           0
# 1071    288.068578       14.136699        68.861861   3.891097           1
# 2924    338.231122       16.276592        47.931639   4.254477           0
# 1207    508.262754       14.058461        40.916811   3.190128           1
#
# [2457 rows x 10 columns]

# %%
water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2457 entries, 2118 to 1207
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2088 non-null   float64
#  1   Hardness         2457 non-null   float64
#  2   Solids           2457 non-null   float64
#  3   Chloramines      2457 non-null   float64
#  4   Sulfate          1866 non-null   float64
#  5   Conductivity     2457 non-null   float64
#  6   Organic_carbon   2457 non-null   float64
#  7   Trihalomethanes  2330 non-null   float64
#  8   Turbidity        2457 non-null   float64
#  9   Drinkable        2457 non-null   object
#  10  Potability       2457 non-null   int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 230.3+ KB

# %%
fig, axs = plt.subplots(1, 3, figsize = (12,9))
axs[0].boxplot(water['ph'].dropna(), meanline = True)
axs[1].boxplot(water['Sulfate'].dropna(), meanline = True)
axs[2].boxplot(water['Trihalomethanes'].dropna(), meanline = True)



axs[0].set_title('ph')
axs[1].set_title('Sulfate')
axs[2].set_title('Trihalomethanes')
# Out:
# Text(0.5, 1.0, 'Trihalomethanes')

# %%
plt.hist(water['ph'].dropna())
plt.axvline(water['ph'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(water['ph'].median(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(water['ph'].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(water['ph'].mean()))
plt.text(water['ph'].median()*1.1, max_ylim*0.8, 'Median: {:.2f}'.format(water['ph'].median()))
plt.title('ph')
plt.show()

# %%
plt.hist(water['Sulfate'].dropna())
plt.axvline(water['Sulfate'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(water['Sulfate'].median(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(water['Sulfate'].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(water['Sulfate'].mean()))
plt.text(water['Sulfate'].median()*1.1, max_ylim*0.8, 'Median: {:.2f}'.format(water['Sulfate'].median()))
plt.title('Sulfate')
plt.show()

# %%
plt.hist(water['Trihalomethanes'].dropna())
plt.axvline(water['Trihalomethanes'].mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(water['Trihalomethanes'].median(), color='k', linestyle='dashed', linewidth=1)
min_ylim, max_ylim = plt.ylim()
plt.text(water['Trihalomethanes'].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(water['Trihalomethanes'].mean()))
plt.text(water['Trihalomethanes'].median()*1.1, max_ylim*0.8, 'Median: {:.2f}'.format(water['Trihalomethanes'].median()))
plt.title('Trihalomethanes')
plt.show()

# %%
water.drop("Drinkable", axis=1, inplace=True)

# %%
water
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2118  8.884935  145.277706  17621.390115     8.267974  341.477474
# 1567       NaN  187.043283  24634.552443     9.081880         NaN
# 69    7.261551  179.889788  24964.777703     5.837086  349.269271
# 2439  7.895769  168.724047  28723.617627     9.341475  353.976181
# 1582  9.723377  190.897421   9076.646483     9.752088  357.384709
# ...        ...         ...           ...          ...         ...
# 101   7.348845  223.264940  11519.046527     8.889559         NaN
# 1734  3.928556  191.665998  17328.161457     7.692417  306.479558
# 1071  7.774468  216.752872  22316.398284     7.947534  385.043438
# 2924  7.833980  203.169408  11174.274760     6.246502  394.890809
# 1207       NaN  221.675463  10117.084438     8.026586  356.211614
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2118    286.890777       15.194724        42.289054   4.714163           0
# 1567    443.843399       11.053925        74.108180   3.498717           1
# 69      501.182781       17.287713        50.993006   3.636364           0
# 2439    517.436676       11.992772        79.860552   4.391731           1
# 1582    443.037417       13.307824        62.826687   4.072063           1
# ...            ...             ...              ...        ...         ...
# 101     494.158434       18.145374        73.715522   4.880875           0
# 1734    406.085614        9.578602        45.480738   5.060836           0
# 1071    288.068578       14.136699        68.861861   3.891097           1
# 2924    338.231122       16.276592        47.931639   4.254477           0
# 1207    508.262754       14.058461        40.916811   3.190128           1
#
# [2457 rows x 10 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.NaN, strategy = 'mean')
water_imputed =pd.DataFrame(imp.fit_transform(water))
water_imputed.columns=water.columns
water_imputed.index=water.index

# %%
water_imputed
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2118  8.884935  145.277706  17621.390115     8.267974  341.477474
# 1567  7.081348  187.043283  24634.552443     9.081880  334.238580
# 69    7.261551  179.889788  24964.777703     5.837086  349.269271
# 2439  7.895769  168.724047  28723.617627     9.341475  353.976181
# 1582  9.723377  190.897421   9076.646483     9.752088  357.384709
# ...        ...         ...           ...          ...         ...
# 101   7.348845  223.264940  11519.046527     8.889559  334.238580
# 1734  3.928556  191.665998  17328.161457     7.692417  306.479558
# 1071  7.774468  216.752872  22316.398284     7.947534  385.043438
# 2924  7.833980  203.169408  11174.274760     6.246502  394.890809
# 1207  7.081348  221.675463  10117.084438     8.026586  356.211614
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2118    286.890777       15.194724        42.289054   4.714163         0.0
# 1567    443.843399       11.053925        74.108180   3.498717         1.0
# 69      501.182781       17.287713        50.993006   3.636364         0.0
# 2439    517.436676       11.992772        79.860552   4.391731         1.0
# 1582    443.037417       13.307824        62.826687   4.072063         1.0
# ...            ...             ...              ...        ...         ...
# 101     494.158434       18.145374        73.715522   4.880875         0.0
# 1734    406.085614        9.578602        45.480738   5.060836         0.0
# 1071    288.068578       14.136699        68.861861   3.891097         1.0
# 2924    338.231122       16.276592        47.931639   4.254477         0.0
# 1207    508.262754       14.058461        40.916811   3.190128         1.0
#
# [2457 rows x 10 columns]

# %%
water_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2457 entries, 2118 to 1207
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2457 non-null   float64
#  1   Hardness         2457 non-null   float64
#  2   Solids           2457 non-null   float64
#  3   Chloramines      2457 non-null   float64
#  4   Sulfate          2457 non-null   float64
#  5   Conductivity     2457 non-null   float64
#  6   Organic_carbon   2457 non-null   float64
#  7   Trihalomethanes  2457 non-null   float64
#  8   Turbidity        2457 non-null   float64
#  9   Potability       2457 non-null   float64
# dtypes: float64(10)
# memory usage: 211.1 KB

# %%
features = water_imputed.drop(columns = 'Potability').columns
X = water_imputed[features]

target = water_imputed['Potability']
y = target

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify = y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression(random_state = 42)

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
log_model.predict(X_train)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
plt.figure(figsize=(10,5))
plt.grid(False)
plot_confusion_matrix(log_model, X_train, y_train)

# %%
from sklearn.tree import DecisionTreeClassifier

water_dt = DecisionTreeClassifier(random_state = 42, max_depth = 5)
water_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_test_pred = water_dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[321,  54],
#        [177,  63]])

# %%
plot_confusion_matrix(water_dt, X_test, y_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.86      0.74       375
#          1.0       0.54      0.26      0.35       240
#
#     accuracy                           0.62       615
#    macro avg       0.59      0.56      0.54       615
# weighted avg       0.60      0.62      0.59       615

# %% [markdown]
# ## Polynomial feature (2)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=2)
poly_water = poly.fit_transform(X)
water_columns = poly.get_feature_names(X.columns)
poly_water = pd.DataFrame(poly_water, columns=water_columns)
poly_water.head()
# Out:
#      1        ph    Hardness        Solids  Chloramines     Sulfate  \
# 0  1.0  8.884935  145.277706  17621.390115     8.267974  341.477474
# 1  1.0  7.081348  187.043283  24634.552443     9.081880  334.238580
# 2  1.0  7.261551  179.889788  24964.777703     5.837086  349.269271
# 3  1.0  7.895769  168.724047  28723.617627     9.341475  353.976181
# 4  1.0  9.723377  190.897421   9076.646483     9.752088  357.384709
#
#    Conductivity  Organic_carbon  Trihalomethanes  Turbidity  ...  \
# 0    286.890777       15.194724        42.289054   4.714163  ...
# 1    443.843399       11.053925        74.108180   3.498717  ...
# 2    501.182781       17.287713        50.993006   3.636364  ...
# 3    517.436676       11.992772        79.860552   4.391731  ...
# 4    443.037417       13.307824        62.826687   4.072063  ...
#
#    Conductivity^2  Conductivity Organic_carbon  Conductivity Trihalomethanes  \
# 0    82306.317792                  4359.226083                  12132.339603
# 1   196996.963206                  4906.211473                  32892.426679
# 2   251184.179714                  8664.304214                  25556.816773
# 3   267740.713580                  6205.500248                  41322.778478
# 4   196282.152799                  5895.863879                  27834.573330
#
#    Conductivity Turbidity  Organic_carbon^2  Organic_carbon Trihalomethanes  \
# 0             1352.450015        230.879628                      642.570494
# 1             1552.882367        122.189249                      819.186238
# 2             1822.483113        298.865030                      881.552475
# 3             2272.442865        143.826588                      957.749416
# 4             1804.076429        177.098174                      836.086486
#
#    Organic_carbon Turbidity  Trihalomethanes^2  Trihalomethanes Turbidity  \
# 0                 71.630411        1788.364104                 199.357514
# 1                 38.674552        5492.022391                 259.283537
# 2                 62.864421        2600.286707                 185.429142
# 3                 52.669034        6377.707739                 350.726088
# 4                 54.190302        3947.192658                 255.834252
#
#    Turbidity^2
# 0    22.223337
# 1    12.241019
# 2    13.223144
# 3    19.287304
# 4    16.581700
#
# [5 rows x 55 columns]

# %%
X_poly_train, X_poly_test, y_poly_train, y_poly_test = train_test_split(poly_water, y, random_state=42, test_size=0.25)

# %% [markdown]
# ## Decision tree

# %%
water_dt = DecisionTreeClassifier(max_depth=15, min_samples_leaf=4, random_state=42)
water_dt.fit(X_poly_train, y_poly_train)

y_pred_test = water_dt.predict(X_poly_test)
confusion_matrix(y_poly_test, y_pred_test)

print(classification_report(y_poly_test, y_pred_test))
plot_confusion_matrix(water_dt, X_poly_test, y_poly_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.82      0.73       380
#          1.0       0.52      0.31      0.39       235
#
#     accuracy                           0.63       615
#    macro avg       0.59      0.57      0.56       615
# weighted avg       0.60      0.63      0.60       615

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Logistic Regression

# %%
scaler=StandardScaler()
scaler.fit(X_poly_train)
X_train_scaled = scaler.transform(X_poly_train)
X_test_scaled = scaler.transform(X_poly_test)

# %%
lm_water = LogisticRegression(max_iter=500)
lm_water.fit(X_train_scaled, y_poly_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
y_lm_pred_test = lm_water.predict(X_poly_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy = accuracy_score(y_poly_test, y_lm_pred_test)
accuracy
# Out:
# 0.3821138211382114

# %%
print(classification_report(y_poly_test, y_lm_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.01      0.02       380
#          1.0       0.38      0.99      0.55       235
#
#     accuracy                           0.38       615
#    macro avg       0.44      0.50      0.28       615
# weighted avg       0.45      0.38      0.22       615

# %%
plot_confusion_matrix(lm_water, X_test_scaled, y_poly_test)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors

# %%
X_t, X_val, y_t, y_val = train_test_split(X_poly_train, y_poly_train,
                                          random_state=42,
                                          test_size=0.25)

water_knn = KNeighborsClassifier(n_neighbors=10, p=1)

water_knn.fit(X_t, y_t)

y_knn_pred_test = water_knn.predict(X_val)

print(classification_report(y_val, y_knn_pred_test))
plot_confusion_matrix(water_knn, X_val, y_val)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.90      0.70       267
#          1.0       0.42      0.10      0.17       194
#
#     accuracy                           0.56       461
#    macro avg       0.50      0.50      0.43       461
# weighted avg       0.51      0.56      0.48       461

# %% [markdown]
# ## Random Forest classifier

# %%
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier,\
ExtraTreesClassifier, VotingClassifier
from sklearn.model_selection import GridSearchCV

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("rfc", RandomForestClassifier())
])

grid = {
    "rfc__n_estimators" : [200, 300, 500],
    "rfc__max_depth": [5, 10, 15],
    "rfc__criterion": ["gini", "entropy"],
#     "rfc__class_weight": ["balanced"],
#     "min_samples_leaf" : range(3,10),
#     "rfc__max_features": [2,4,6, None]
    }

gs=GridSearchCV(pipeline, grid, cv=5, scoring="accuracy", n_jobs=-1, verbose=1)

gs.fit(X_poly_train, y_poly_train)

y_test_pred=gs.predict(X_poly_test)

# Single best score achieved across all params (min_samples_split)
print(gs.best_score_)

# Dictionary containing the parameters (min_samples_split) used to generate that score
# print(gs.best_params_)

# Actual model object fit with those best parameters
# Shows default parameters that we did not specify
print(gs.best_estimator_)
#Identify the best score during fitting with cross-validation
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:   44.7s finished
# 0.6764404383174266
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rfc',
#                  RandomForestClassifier(max_depth=15, n_estimators=200))])

# %%
plot_confusion_matrix(gs, X_poly_train, y_poly_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00a943f1ee9c> in <module>
# ----> 1 plot_confusion_matrix(gs, X_poly_train, y_poly_train)
#
# NameError: name 'plot_confusion_matrix' is not defined

# %%
print(classification_report(y_poly_test, y_test_pred))
plot_confusion_matrix(gs, X_poly_test, y_poly_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.89      0.77       380
#          1.0       0.66      0.34      0.45       235
#
#     accuracy                           0.68       615
#    macro avg       0.67      0.61      0.61       615
# weighted avg       0.67      0.68      0.65       615

# %% [markdown]
# ## one feature (ph)

# %%
X1=water_imputed.ph
y1=water_imputed.Potability

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, random_state=42, test_size=0.25)

X_train1=X_train1.values.reshape(-1,1)
X_test1=X_test1.values.reshape(-1,1)

scaler=StandardScaler()
scaler.fit(X_train1)
X_train_scaled1 = scaler.transform(X_train1)
X_test_scaled1 = scaler.transform(X_test1)


# dt = DecisionTreeClassifier(max_depth=5)
# dt.fit(X_train_scaled, y_train)

lm = LogisticRegression(random_state=42)
lm.fit(X_train_scaled1, y_train1)
# Out:
# LogisticRegression(random_state=42)

# %%
y_test_pred1 = lm.predict(X_test_scaled1)

print(classification_report(y_test1, y_test_pred1))
plot_confusion_matrix(lm, X_test_scaled1, y_test1)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.76       380
#          1.0       0.00      0.00      0.00       235
#
#     accuracy                           0.62       615
#    macro avg       0.31      0.50      0.38       615
# weighted avg       0.38      0.62      0.47       615
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
water_imputed.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.056517 -0.089268    -0.027988  0.020339
# Hardness         0.056517  1.000000 -0.042984    -0.035643 -0.070818
# Solids          -0.089268 -0.042984  1.000000    -0.091705 -0.182993
# Chloramines     -0.027988 -0.035643 -0.091705     1.000000  0.032952
# Sulfate          0.020339 -0.070818 -0.182993     0.032952  1.000000
# Conductivity     0.019248 -0.021388  0.000157    -0.021112 -0.019560
# Organic_carbon   0.048423  0.007359  0.024548    -0.006350  0.013032
# Trihalomethanes  0.004698 -0.001790 -0.025304     0.005564 -0.011966
# Turbidity       -0.028159 -0.017436  0.014920     0.007922 -0.008544
# Potability       0.011372 -0.000571  0.025698     0.016957 -0.001321
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.019248        0.048423         0.004698  -0.028159
# Hardness            -0.021388        0.007359        -0.001790  -0.017436
# Solids               0.000157        0.024548        -0.025304   0.014920
# Chloramines         -0.021112       -0.006350         0.005564   0.007922
# Sulfate             -0.019560        0.013032        -0.011966  -0.008544
# Conductivity         1.000000        0.010328         0.006446   0.000507
# Organic_carbon       0.010328        1.000000         0.014952  -0.005719
# Trihalomethanes      0.006446        0.014952         1.000000  -0.017962
# Turbidity            0.000507       -0.005719        -0.017962   1.000000
# Potability           0.009651       -0.014839        -0.005598   0.004186
#
#                  Potability
# ph                 0.011372
# Hardness          -0.000571
# Solids             0.025698
# Chloramines        0.016957
# Sulfate           -0.001321
# Conductivity       0.009651
# Organic_carbon    -0.014839
# Trihalomethanes   -0.005598
# Turbidity          0.004186
# Potability         1.000000

# %% [markdown]
# ## 2 Features

# %%
columns=["ph", "Solids", "Chloramines", "Turbidity", "Conductivity"]
X2=water_imputed[columns]
y2=water_imputed.Potability

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, random_state=42, test_size=0.25)

# X_train=X_train.values.reshape(-1,1)
# X_test=X_test.values.reshape(-1,1)

scaler=StandardScaler()
scaler.fit(X_train2)
X_train_scaled2 = scaler.transform(X_train2)
X_test_scaled2 = scaler.transform(X_test2)

# dt = DecisionTreeClassifier(max_depth=5)
# dt.fit(X_train_scaled, y_train)

lm = LogisticRegression(random_state=42)
lm.fit(X_train_scaled2, y_train2)

y_test_pred = lm.predict(X_test_scaled2)

print(classification_report(y_test, y_test_pred))
plot_confusion_matrix(lm, X_test_scaled2, y_test2)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      1.00      0.76       380
#          1.0       0.00      0.00      0.00       235
#
#     accuracy                           0.62       615
#    macro avg       0.31      0.50      0.38       615
# weighted avg       0.38      0.62      0.47       615
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
